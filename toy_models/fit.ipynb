# %%
# !pip install numpy torch sympy mod blobfile pandas seaborn matplotlib tqdm einops wandb

import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))

from contextlib import suppress
from dataclasses import dataclass, asdict
from datetime import datetime
from typing import Callable, Literal, Optional, Union, Tuple, List
from copy import deepcopy

import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch import optim
import wandb
from tqdm.notebook import tqdm
import ipywidgets as widgets
import wandb

import matplotlib as mpl
from matplotlib.colors import LogNorm
import seaborn as sns
import matplotlib.pyplot as plt

from patterns.dataset import ModularArithmetic, Operator
from patterns.transformer import Transformer
from patterns.utils import generate_run_name
from patterns.learner import Config, GrokkingLearner, GrokkingConfig

from unifying.sweep import get_history, handle_outliers

DEFAULT_MODULUS = 113
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

sns.set_theme(style="darkgrid")
# Out:
# Requirement already satisfied: numpy in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (1.24.2)
# Requirement already satisfied: torch in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (1.13.1)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 60.6 MB/s eta 0:00:00a 0:00:01
# Collecting mod
#   Downloading mod-0.3.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: blobfile in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (2.0.2)
# Collecting pandas
#   Downloading pandas-2.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 72.8 MB/s eta 0:00:0000:0100:01
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 KB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: tqdm in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (4.65.0)
# Requirement already satisfied: einops in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: wandb in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (0.13.11)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from torch) (4.5.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: wheel in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Requirement already satisfied: setuptools in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (59.6.0)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 55.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.25.3 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from blobfile) (1.26.15)
# Requirement already satisfied: pycryptodomex~=3.8 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from blobfile) (3.17)
# Requirement already satisfied: lxml~=4.9 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from blobfile) (4.9.2)
# Requirement already satisfied: filelock~=3.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from blobfile) (3.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 KB 48.5 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 KB 40.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: packaging>=20.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (23.0)
# Requirement already satisfied: cycler>=0.10 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (2.28.2)
# Requirement already satisfied: setproctitle in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (1.3.2)
# Requirement already satisfied: pathtools in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (8.1.3)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (4.22.1)
# Requirement already satisfied: psutil>=5.0.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (5.9.4)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (3.1.31)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (1.17.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (1.4.4)
# Requirement already satisfied: PyYAML in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (6.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: six>=1.4.0 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: idna<4,>=2.5 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Installing collected packages: pytz, mpmath, tzdata, sympy, mod, pandas, seaborn
# Successfully installed mod-0.3.0 mpmath-1.3.0 pandas-2.0.1 pytz-2023.3 seaborn-0.12.2 sympy-1.12 tzdata-2023.3

# %%
# List the devices
# !nvidia-smi
# Out:
# Thu May 11 12:36:51 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 530.41.03              Driver Version: 530.41.03    CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                  Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX 6000 Ada Gener...    Off| 00000000:01:00.0 Off |                  Off |
# | 40%   67C    P2              126W / 300W|   1502MiB / 49140MiB |     26%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2084      G   /usr/lib/xorg/Xorg                            4MiB |
# |    0   N/A  N/A     10260      C   python                                     1494MiB |
# +---------------------------------------------------------------------------------------+

# %%
rw_grokking = get_history("2peyz0vr", "oxsp97s3", unique_cols="weight_decay")
rw_grokking_cleaned = handle_outliers(
    rw_grokking,
    loss_cols=["train/loss"], 
    action="remove",
    unique_cols=["weight_decay"],
    threshold=0.0001,
    late_epochs_ratio=0.6,
)

# %%
wds = rw_grokking_cleaned.weight_decay.unique()
run = rw_grokking_cleaned[rw_grokking_cleaned.weight_decay == wds[-1]]

def rescale_run(run):
    # Changes the steps to fit in the range [0, 100] (following a log scale)
    run = run.copy()
    max_ = np.log(run["_step"].max())
    run["_step"] = np.log(run["_step"]) / max_ * 100

    return run

rescaled_run = rescale_run(run)
rescaled_run.plot(x="_step", y=["test/acc", "train/acc"], figsize=(10, 5))
plt.show()

# %%
class Pattern(nn.Module):
    def __init__(self):
        # 4 scalar parameters: strength, speed, onset, generalization
        super().__init__()
        self.strength = nn.Parameter(torch.rand(1)[0])
        self.speed = nn.Parameter(torch.rand(1)[0])
        self.onset = nn.Parameter(torch.rand(1)[0] * 100)
        self.generalization = nn.Parameter(torch.rand(1)[0])

    def forward(self, t): 
        return self.strength * F.sigmoid(self.speed * (t - self.onset))

    def __repr__(self):
        return f"Pattern(strength={self.strength.data.float()}, speed={self.speed.data.float()}, onset={self.onset.data.float()}, generalization={self.generalization.data.float()})"

class GrokkingModel(nn.Module):
    def __init__(self, num_patterns: int = 3):
        super().__init__()
        self.num_patterns = num_patterns 
        self.patterns = nn.ModuleList([Pattern() for _ in range(num_patterns)])
        
        self.binary_mask = torch.tensor(
            [[int(i) for i in bin(j)[2:].zfill(num_patterns)] for j in range(2 ** num_patterns)]
        ).float()

        self.counts = self.binary_mask.sum(dim=1)

        # Register buffer for generalizations
        # self._generalizations = torch.zeros(2 ** num_patterns)
        self.register_buffer("_generalizations", torch.zeros(2 ** num_patterns))

    # def predictivenesses(self, t):
    #     return torch.stack([p(t) for p in self.patterns])
        
    # def forward(self, t):
    #     return 1 - torch.prod(1 - self.predictivenesses(t), dim=0)
    
    # def usages(self, t):
    #     preds = self.predictivenesses(t)
    #     usages = torch.prod(preds.T * self.binary_mask + (1 - preds.T) * (1 - self.binary_mask), dim=1)
    #     return usages

    # def gs(self):
    #     return torch.stack([p.generalization for p in self.patterns])

    # def generalizations(self):
    #     generalizations = torch.sum(self.gs().T * self.binary_mask, dim=1) / self.counts
    #     generalizations[0] = 0
    #     return generalizations

    # def test(self, t):
    #     return torch.sum(self.generalizations() * self.usages(t), dim=0)    
    
    def predictivenesses(self, t):
        return torch.stack([p(t) for p in self.patterns])
        
    def forward(self, t):
        prod = 1
    
        for p in self.patterns:
            prod *= 1 - p(t)
        
        return 1 - prod
        
    def usages(self, t):
        preds = [p(t) for p in self.patterns]
        usages = torch.ones(2 ** self.num_patterns)

        for i in range(2 ** self.num_patterns):
            for j in range(self.num_patterns):
                if i & (1 << j):
                    usages[i] *= preds[j]
                else:
                    usages[i] *= (1 - preds[j])

        return usages

    def gs(self):
        return torch.stack([p.generalization for p in self.patterns])

    def generalizations(self):
        self._generalizations *= 0

        for i in range(2 ** self.num_patterns):
            count = 0
            for j in range(self.num_patterns):
                if i & (1 << j):
                    # print(i, j, self.patterns[j].generalization, generalizations[i])
                    self._generalizations[i] += self.patterns[j].generalization
                    count += 1

            if count > 0:
                self._generalizations[i] /= count

        return self._generalizations

    def test(self, t):
        return torch.sum(self.generalizations() * self.usages(t), dim=0)  

torch.manual_seed(23)
gm = GrokkingModel()

def plot_patterns(gm):
    ts = torch.linspace(0, 100, 100).T
    train_preds = [gm(t).detach().numpy() for t in ts]
    test_preds = [gm.test(t).detach().numpy() for t in ts]

    plt.plot(ts, train_preds, label="train", color="blue")
    plt.plot(ts, test_preds, label="test", color="red")

plot_patterns(gm)
# Out:
# /tmp/ipykernel_11331/2684812831.py:104: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3277.)
#   ts = torch.linspace(0, 100, 100).T
# /home/jesse/Projects/pattern-learning/.venv/lib/python3.10/site-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")

# %%
def fit_patterns(run):
    gm = GrokkingModel()
    ts = torch.tensor(run._step.values).float()
    train_ys = torch.tensor(run["train/acc"].values).float()
    test_ys = torch.tensor(run["test/acc"].values).float()

    optimizer = optim.Adam(gm.parameters(), lr=0.00001)
    criterion = nn.MSELoss()
    # Cross-entropy 
    eps = 1e-6
    # criterion = lambda preds, ys: -torch.sum(ys * torch.log(preds + eps) + (1 - ys) * torch.log(1 - preds + eps))
    
    plot_patterns(gm)
    plt.show()

    for epoch in tqdm(range(1000)):
        for t in ts:
            optimizer.zero_grad()
            loss = torch.zeros(1)
            train_preds = gm(t)
            test_preds = gm.test(t)
            loss += criterion(train_preds, train_ys) + criterion(test_preds, test_ys) jJ
            print(loss)
            optimizer.step()

            # gradients
            for p in gm.parameters():
                print(p.grad)
            
            return gm

        if epoch < 10:
            print(f"Epoch {epoch} - loss: {loss.item()}")
            plot_patterns(gm)
            plt.show()

    return gm

gm = fit_patterns(rescaled_run)
# Out:
#   Cell In[5], line 22
#     loss += criterion(train_preds, train_ys) + criterion(test_preds, test_ys) jJ
#                                                                               ^
# SyntaxError: invalid syntax
